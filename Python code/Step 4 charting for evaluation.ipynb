# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.arange(9)

AL_micro_F1 = [0.6308492201039861,0.7023622047244094,0.7663230240549828,0.7839195979899497,0.7787307032590052,0.7755102040816327,0.796116504854369,0.8045977011494253,0.8108974358974359]
AL_macro_F1 = [0.42,0.53,0.62,0.67,0.62,0.66,0.73,0.70, 0.75]
BL_micro_F1 = [0.6308492201039861,0.6746575342465753,0.7272727272727274,0.7668918918918918,0.7478260869565219,0.7745266781411361,0.7824620573355817,0.8040885860306644, 0.795417348608838]
BL_macro_F1 = [0.42,0.54,0.58,0.66,0.65,0.64,0.69,0.7,0.72]



AL_micro_F1 = np.array(AL_micro_F1)
AL_macro_F1 = np.array(AL_macro_F1)
BL_micro_F1 = np.array(BL_micro_F1)
BL_macro_F1 = np.array(BL_macro_F1)

# %%
(AL_micro_F1-BL_micro_F1)*100
# Out:
# array([0.        , 2.77046705, 3.90502968, 1.70277061, 3.09046163,
#        0.09835259, 1.36544475, 0.05091151, 1.54800873])

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))


line_AL_micro_F1, = ax.plot(AL_micro_F1, label='Micro F1')
line_AL_macro_F1, = ax.plot(AL_macro_F1, label='Macro F1')
plt.xticks(x, ['0th (random)','1st','2nd','3rd','4th','5th','6th','7th','8th'])

plt.xlabel('Batch of training data selected by Active Learning')
ax.legend(handles=[line_AL_micro_F1, line_AL_macro_F1], loc='upper left')

for xi,yi in zip(x,AL_micro_F1):

    label = "{:.3f}".format(yi)

    plt.annotate(label, # this is the text
                 (xi,yi), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center
for xi,yi in zip(x,AL_macro_F1):

    label = "{:.3f}".format(yi)

    plt.annotate(label, # this is the text
                 (xi,yi), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center
ax.set_ylim(0.4, 0.85)
# Out:
# (0.4, 0.85)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))


line_AL_micro_F1, = ax.plot(AL_micro_F1, label='AL Micro F1')
line_BL_micro_F1, = ax.plot(BL_micro_F1, label='BL Micro F1')
plt.xticks(x, ['0th (random)','1st','2nd','3rd','4th','5th','6th','7th','8th'])

plt.xlabel('Batch of training data selected')
ax.legend(handles=[line_AL_micro_F1, line_BL_micro_F1],loc='upper left')


for xi,yi in zip(x,AL_micro_F1):

    label = "{:.3f}".format(yi)

    plt.annotate(label, # this is the text
                 (xi,yi), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,15), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center
for xi,yi in zip(x,BL_micro_F1):

    label = "{:.3f}".format(yi)

    plt.annotate(label, # this is the text
                 (xi,yi), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,-15), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center
ax.set_ylim(0.6, 0.85)
# Out:
# (0.6, 0.85)

# %%
AL_class_micro_F1=pd.read_excel('data\AL_micro_f1.xlsx')
BL_class_micro_F1=pd.read_excel('data\BL_micro_f1.xlsx')

# %%
AL_class_micro_F1
# Out:
#    Autonomy_for_companies  Autonomy_for_close_contact_professions  \
# 0                    0.80                                    0.57
# 1                    0.89                                    0.92
# 2                    0.94                                    0.93
# 3                    0.95                                    0.96
# 4                    0.93                                    0.96
# 5                    0.94                                    0.95
# 6                    0.93                                    0.95
# 7                    0.94                                    0.95
# 8                    0.94                                    0.95
#
#    Quality_of_life_for_elderly  Family_value  Feasibility  \
# 0                         0.73          0.35         0.00
# 1                         0.78          0.58         0.00
# 2                         0.82          0.58         0.40
# 3                         0.93          0.63         0.22
# ...

# %%
AL_class_micro_F1.iloc[:,0]
# Out:
# 0    0.80
# 1    0.89
# 2    0.94
# 3    0.95
# 4    0.93
# 5    0.94
# 6    0.93
# 7    0.94
# 8    0.94
# Name: Autonomy_for_companies, dtype: float64

# %%
fig, ax = plt.subplots(10, figsize=(8, 9))
#fig.subplots_adjust(bottom=0,  top=1)

for i in range(9):
    AL, = ax[i].plot(AL_class_micro_F1.iloc[:,i])
    BL, = ax[i].plot(BL_class_micro_F1.iloc[:,i])

AL, = ax[9].plot(AL_class_micro_F1.iloc[:,9], label='AL')
BL, = ax[9].plot(BL_class_micro_F1.iloc[:,9], label='BL')

plt.xlabel('Batch of training data selected')
'''
for i in  ax.flat:
    i.yaxis.set_visible(False)
'''
for i in  ax.flat[:-1]:

    i.xaxis.set_visible(False)   
    
ax[0].legend(handles=[AL,BL],loc='lower right',fontsize=9)    
    
plt.xticks(x, ['0th (random)','1st','2nd','3rd','4th','5th','6th','7th','8th'])
# Out:
# ([<matplotlib.axis.XTick at 0x22ca9c51900>,
# ...
#  [Text(0, 0, '0th (random)'),
#   Text(1, 0, '1st'),
#   Text(2, 0, '2nd'),
#   Text(3, 0, '3rd'),
#   Text(4, 0, '4th'),
#   Text(5, 0, '5th'),
#   Text(6, 0, '6th'),
#   Text(7, 0, '7th'),
#   Text(8, 0, '8th')])

# %%
################################################################################

# %%
################################################################################

# %%
import torch
from sentence_transformers import SentenceTransformer

# %%
def get_vectors(phrases, model):
    """ Embed phrases with SentenceTransformer model.
    """
    return np.array(model.encode(phrases), dtype=np.float)

# %%
from sklearn.preprocessing import normalize
def compute_center(keywords, model):
    
    """ Get the value cluster center as the normalized sum of the embeddings of the keywords + value name.
    """
    # Get value and keywords.
    #keywords = list(context_value_list[value][1])

    # Embed all keywords and value key and take the normalized sum as center.
    vectors = get_vectors(keywords, model)
    center  = normalize([np.sum(vectors, axis=0)])[0]

    return center

# %%
#select model that provide embedding for words
if torch.cuda.is_available():
    #model_keywords_distance=SentenceTransformer('all-mpnet-base-v2', device='cuda')
    model_keywords_distance=SentenceTransformer('all-MiniLM-L6-v2', device='cuda')
    #model_keywords_distance=SentenceTransformer('bert-base-uncased', device='cuda')
else:
    #model_keywords_distance=SentenceTransformer('all-mpnet-base-v2') 
    model_keywords_distance=SentenceTransformer('all-MiniLM-L6-v2') 
    #model_keywords_distance=SentenceTransformer('bert-base-uncased')

# %%
#get cosine distance from a pair of values

from scipy.spatial.distance import cdist
def get_distance(centre1, centre2):
    a=np.expand_dims(centre1, axis=0)
    b=np.expand_dims(centre2, axis=0)
    return float(np.absolute(cdist(a,b, 'cosine'))[0])

# %%
keywords_list1=[]
#keywords_list1.append(['one','two'])
#keywords_list1.append(['single','double'])

keywords_list1.append(['economics', 'work', 'economy', 'economic', 'company', 'employment', 'employee', 'measure', 'catering', 'meter', 'customer', 'income', 'sector', 'impact', 'profession', 'entrepreneur', 'measure', 'track', 'future', 'start', 'need', 'job', 'bankruptcy'])
keywords_list1.append(['hairdresser', 'nail', 'work', 'physiotherapist', 'glove', 'profession', 'pedicure', 'dentist', 'equipment', 'business'])
keywords_list1.append(['nursing', 'visiting', 'family', 'elderly', 'visit', 'visitor', 'care', 'suffering', 'loneliness', 'risk', 'life', 'nursing', 'health', 'measure', 'resident', 'death'])
keywords_list1.append(['support', 'complaint', 'benefit', 'responsibility', 'family', 'contact', 'health', 'care', 'effect', 'loneliness'])
keywords_list1.append(['5m', 'space', 'household', 'feasible', 'away', 'metre', 'measure', 'distance', 'meter', 'risk'])
keywords_list1.append(['nursing', 'family', 'break', 'contact', 'vulnerable', 'metre', 'age', 'social', 'meter', 'risk'])
keywords_list1.append(['sport', 'young', 'pressure', 'develop', 'child', 'measure', 'social', 'development', 'risk', 'school'])
keywords_list1.append(['infect', 'infection', 'family', 'prevent', 'infected', 'spread', 'immune', 'virus', 'care', 'risk'])
keywords_list1.append(['economy', 'family', 'income', 'economic', 'pressure', 'health', 'psychological', 'measure', 'mental', 'effect'])
keywords_list1.append(['unrest', 'reducing', 'future', 'income', 'economic', 'consequence', 'impact', 'disastrous', 'effect', 'risk'])

#keywords_list1

# %%
topic_embeddings_list1=[]
for i in keywords_list1:
    topic_embeddings_list1.append(compute_center(i, model_keywords_distance ))
# Out:
# C:\Users\tim_wsh\AppData\Local\Temp\ipykernel_12584\2500773109.py:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return np.array(model.encode(phrases), dtype=np.float)
# C:\Users\tim_wsh\AppData\Local\Temp\ipykernel_12584\2500773109.py:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %%
len(topic_embeddings_list1)
# Out:
# 10

# %%
len(topic_embeddings_list1[0])
# Out:
# 384

# %%
name_list1=['Autonomy for companies',
'Autonomy for close contact professions',
'Quality of life for elderly',
'Family value',
'Feasibility',
'Acceptance of exception',
'The need of schooling',
'Working safety',
'Well-being',
'Reduce adverse effect'
]

# %%
###############################################################################

# %%
import yaml
with open('data\lists.yaml', 'r') as file:
    #yaml.safe_load(file)
    value_lists_yaml = yaml.safe_load(file)

# %%
value_lists_yaml.keys()
# Out:
# dict_keys(['covid', 'energy', 'schwartz'])

# %%
keywords_Axies_list1=[]
name_Axies_list1=[]
for i in value_lists_yaml['covid']['group_1']:
    keywords_Axies_list1.append(i['keywords'])
    name_Axies_list1.append(i['value_name'])

# %%
keywords_Axies_list2=[]
name_Axies_list2=[]
for i in value_lists_yaml['covid']['group_2']:
    keywords_Axies_list2.append(i['keywords'])
    name_Axies_list2.append(i['value_name'])

# %%
topic_embeddings_Axies_list1=[]
for i in keywords_Axies_list1:
    topic_embeddings_Axies_list1.append(compute_center(i, model_keywords_distance ))
# Out:
# C:\Users\tim_wsh\AppData\Local\Temp\ipykernel_12584\2500773109.py:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return np.array(model.encode(phrases), dtype=np.float)
# C:\Users\tim_wsh\AppData\Local\Temp\ipykernel_12584\2500773109.py:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %%
topic_embeddings_Axies_list2=[]
for i in keywords_Axies_list2:
    topic_embeddings_Axies_list2.append(compute_center(i, model_keywords_distance ))
# Out:
# C:\Users\tim_wsh\AppData\Local\Temp\ipykernel_12584\2500773109.py:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return np.array(model.encode(phrases), dtype=np.float)
# C:\Users\tim_wsh\AppData\Local\Temp\ipykernel_12584\2500773109.py:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %%
len(topic_embeddings_Axies_list1)
# Out:
# 11

# %%
len(topic_embeddings_Axies_list2)
# Out:
# 9

# %%
name_Axies_list1
# Out:
# ['fairness',
#  'care',
#  'being social',
#  'enjoyment',
#  'economic prosperity',
#  'nuclear family',
#  'control',
#  'safety',
#  'autonomy',
#  'well-being',
#  'feasibility']

# %%
cosine_list=pd.DataFrame()

for i ,iv in enumerate(name_list1):
    #print(iv)
    score_list=[]
    for j ,jv in enumerate(name_Axies_list1):
        score_list.append(get_distance(topic_embeddings_list1[i], topic_embeddings_Axies_list1[j]))
    cosine_list[iv]=pd.Series(score_list)

# %%
cosine_list['index']=name_Axies_list1
cosine_list=cosine_list.set_index('index')

# %%
cosine_list
# Out:
#                      Autonomy for companies  \
# index
# fairness                           0.367350
# care                               0.430458
# being social                       0.329556
# enjoyment                          0.348336
# economic prosperity                0.088063
# nuclear family                     0.348284
# control                            0.289336
# safety                             0.457001
# autonomy                           0.313495
# well-being                         0.356020
# feasibility                        0.279272
#
#                      Autonomy for close contact professions  \
# index
# fairness                                           0.490567
# care                                               0.510089
# being social                                       0.377071
# enjoyment                                          0.414118
# economic prosperity                                0.269248
# ...

# %%
from pylab import rcParams
import seaborn as sb
import matplotlib.pyplot as plt

# %%
rcParams['figure.figsize'] = 14.7,8.27
hm=sb.heatmap(1-cosine_list,
           #yticklabels=raw_context_value_list.keys(), 
           #xticklabels=raw_context_value_list.keys(), 
           cmap="YlGnBu",
          annot=True)
hm.set(xlabel ="Consolidated value list", ylabel = "Axies COVID-G1 list")
# Out:
# [Text(0.5, 61.6922222222222, 'Consolidated value list'),
#  Text(154.47222222222223, 0.5, 'Axies COVID-G1 list')]

# %%
################################################

# %%
cosine_list=pd.DataFrame()

for i ,iv in enumerate(name_list1):
    #print(iv)
    score_list=[]
    for j ,jv in enumerate(name_Axies_list2):
        score_list.append(get_distance(topic_embeddings_list1[i], topic_embeddings_Axies_list2[j]))
    cosine_list[iv]=pd.Series(score_list)

# %%
cosine_list['index']=name_Axies_list2
cosine_list=cosine_list.set_index('index')

# %%
cosine_list
# Out:
#                            Autonomy for companies  \
# index
# Mental health                            0.388884
# Safety and Health                        0.313625
# Economic security                        0.103912
# Acceptance of misbehavior                0.342243
# Pleasure                                 0.282588
# Conformity                               0.234039
# Equality                                 0.360592
# Belonging to a group                     0.307905
# Autonomy                                 0.326045
#
#                            Autonomy for close contact professions  \
# index
# Mental health                                            0.391149
# Safety and Health                                        0.325950
# Economic security                                        0.334870
# Acceptance of misbehavior                                0.407963
# Pleasure                                                 0.351650
# ...

# %%
rcParams['figure.figsize'] = 14.7,8.27
hm=sb.heatmap(1-cosine_list,
           #yticklabels=raw_context_value_list.keys(), 
           #xticklabels=raw_context_value_list.keys(), 
           cmap="YlGnBu",
          annot=True)
hm.set(xlabel ="Consolidated value list", ylabel = "Axies COVID-G2 list")
# Out:
# [Text(0.5, 61.6922222222222, 'Consolidated value list'),
#  Text(154.47222222222223, 0.5, 'Axies COVID-G2 list')]
